# %% [markdown]
# # Getting the billboard data
#
# ## Description
# This notebook explains the functionality related to querying and processing the data into the dataset used later for the models. The documentation is in two major parts which are retrieving the data from APIs and processing the data into ready to use dataset.<br />
#
# All functionality used here is stored in **data** folder and you can check out the source there (types are in **data/types/** to give more insight on what structure the used variables have). <br />An overview of the function that is used is provided here.<br />
#
#
# [Requirements](#requirements)

# %%
# First set up the environment. Code sources are in folders which are in the parent folder of this notebooks scope.
import sys; sys.path.insert(0, '..') # add parent folder path, now files are queriable from parent folder

# Install Kaggle api package (not included in the docker image) and spotipy
# !pip install kaggle spotipy

# Install packages for fuzzywuzzy
# This is used to calculate ratio between two uneven string
# %conda install -c conda-forge python-levenshtein
# %pip install fuzzywuzzy
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: spotipy in /opt/conda/lib/python3.9/site-packages (2.19.0)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.9/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.9/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from kaggle) (2.26.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from kaggle) (4.62.3)
# Collecting python-slugify
#   Downloading python_slugify-5.0.2-py2.py3-none-any.whl (6.7 kB)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.9/site-packages (from kaggle) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->kaggle) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->kaggle) (3.1)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 998 kB/s eta 0:00:01
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=7c8ceea7917c949d0e897969c3007faf46006ad2c1ab1267e22a98e3a2589491
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ac/b2/c3/fa4706d469b5879105991d1c8be9a3c2ef329ba9fe2ce5085e
# Successfully built kaggle
# Installing collected packages: text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.12 python-slugify-5.0.2 text-unidecode-1.3
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - python-levenshtein
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py39hf3d152e_1         145 KB  conda-forge
#     python-levenshtein-0.12.2  |   py39h3811e60_1          80 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         364 KB
#
# The following NEW packages will be INSTALLED:
#
#   python-levenshtein conda-forge/linux-64::python-levenshtein-0.12.2-py39h3811e60_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2021.5.30-ha878542_0 --> 2021.10.8-ha878542_0
#   certifi                          2021.5.30-py39hf3d152e_0 --> 2021.10.8-py39hf3d152e_1
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# python-levenshtein-0 | 80 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## <a id='query'></a>Query
# In this part data is fetched from different sources with APIs.

# %%
# All imports + initialize the Spotify API
from data.query.util import initializeSpotifyAPI, saveJson
api = initializeSpotifyAPI()

from data.query.billboard import getBillboardData
from data.query.spotify_api import getSpotifyDataFromBillboardSongs, getSpotifyAudioFeatures, getSongsWithAlbums

# %% [markdown]
# ### <a id='billboard'></a>Billboard Top 100 dataset from Kaggle

# %% [markdown]
# ### Dataset
# First query the dataset from Kaggle. https://www.kaggle.com/dhruvildave/billboard-the-hot-100-songs
# **downloadBillboardData** is quite straight forward, it takes in the name of the dataset as a string handles the Kaggle credentials and calls **downloadKaggleDataset** which will download the dataset in the defined path.
#
# As default the path is set to **data/datasets/billboard/** if you do not have the folders for this path, they are created.
#
# *Credentials can be passed to the function directly (check source)

# %%
from data.query.billboard import downloadBillboardData

# Download the kaggle billboard dataset
datasetName = 'dhruvildave/billboard-the-hot-100-songs'
downloadBillboardData(datasetName)

# %% [markdown]
# Now the billboard songs are queryable with **getBillboardData** function. It reads the zip file that contains the dataset, takes the file that is given as input (default charts.csv) and parses the required data. Finally it returns list of billboard songs.

# %%
# Fetch billboard song data from zip file (kaggle ds)
billboardTracks = getBillboardData('../data/datasets/billboard/billboard-the-hot-100-songs.zip')

# %%
# View 10 first songs
print(billboardTracks[:10])
# Out:
# [{'rank': '1', 'song': 'Butter', 'artist': 'BTS', 'last-week': '1', 'peak-rank': '1', 'weeks-on-board': '7', 'date': '2021-07-17'}, {'rank': '2', 'song': 'Good 4 U', 'artist': 'Olivia Rodrigo', 'last-week': '2', 'peak-rank': '1', 'weeks-on-board': '8', 'date': '2021-07-17'}, {'rank': '3', 'song': 'Levitating', 'artist': 'Dua Lipa Featuring DaBaby', 'last-week': '4', 'peak-rank': '2', 'weeks-on-board': '40', 'date': '2021-07-17'}, {'rank': '4', 'song': 'Kiss Me More', 'artist': 'Doja Cat Featuring SZA', 'last-week': '3', 'peak-rank': '3', 'weeks-on-board': '13', 'date': '2021-07-17'}, {'rank': '5', 'song': 'Montero (Call Me By Your Name)', 'artist': 'Lil Nas X', 'last-week': '8', 'peak-rank': '1', 'weeks-on-board': '15', 'date': '2021-07-17'}, {'rank': '6', 'song': 'Bad Habits', 'artist': 'Ed Sheeran', 'last-week': '5', 'peak-rank': '5', 'weeks-on-board': '2', 'date': '2021-07-17'}, {'rank': '7', 'song': 'Leave The Door Open', 'artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'last-week': '6', 'peak-rank': '1', 'weeks-on-board': '18', 'date': '2021-07-17'}, {'rank': '8', 'song': 'Peaches', 'artist': 'Justin Bieber Featuring Daniel Caesar & Giveon', 'last-week': '7', 'peak-rank': '1', 'weeks-on-board': '16', 'date': '2021-07-17'}, {'rank': '9', 'song': 'Save Your Tears', 'artist': 'The Weeknd & Ariana Grande', 'last-week': '9', 'peak-rank': '1', 'weeks-on-board': '30', 'date': '2021-07-17'}, {'rank': '10', 'song': 'Deja Vu', 'artist': 'Olivia Rodrigo', 'last-week': '10', 'peak-rank': '3', 'weeks-on-board': '14', 'date': '2021-07-17'}]

# %% [markdown]
# ### <a id='ids'></a>Spotify song ids

# %% [markdown]
# Now that the billboard song data is fetched from Kaggle. Next the songs are needed to map to songs in spotify database.
#
# Unfortunately the dataset doesn't have Spotify IDs ready to use and query the song information.
#
# To get the IDs the songs have to be searched first with the song and artist name. **getSpotifyDataFromBillboardSongs** will do the trick.
#
# Querying the songs is not totally straight forward. The song names can differ in billboard data and spotify data + it can be that the song is not available in spotify (market, artist etc. reasons).
#
# Matching the results with billboard data information is done so that first just the song is used as the query string. If the song names match and the billboard data artist is in the list of artists that the song has listed, all good the song is added to the data.
#
# The songs that do not match directly, a new query is made where song and artist name is used as query string. If the tokenized sets of the query string and spotify result song + artists string matches close enough it is added to the data. Mainly this collect songs with unknown characters in song or artists names or song name having for example "feat. 'some artist' " in the song name, but in Spotify data the featured artists are put in artist list and then the song names do not match.
#
# This approach raises a second problem which is that in Spotify there are remix, instrumental and or karaoke versions. These songs are not wanted in the data so blacklisting is implemented. All song names containing these are blacklisted and not added (with few exceptions that are whitelisted).
#
# The billboard data has top 100 songs per week , therefore a song that is in the top list two weeks in row will be queried two times. During this querying all the duplicates are ignored.
#
# Finally all search results are stored in json file.
#
# *Total number songs to query prints total number of songs in billboard dataset, but one song is queried only ones
#
# *Takes about 2-3 hours to query the full dataset

# %%
# Query song information from spotify with song names
queryResultPath = '../data/datasets/spotify/query_results.json'
billboardSpotifyTrackData = getSpotifyDataFromBillboardSongs(api, billboardTracks, savePath=queryResultPath)
# Out:
# Total number of songs to query:  328487
# Queried songs:  0
# Actual queries:  0
# Queried songs:  1000
# Actual queries:  231
# Queried songs:  2000
# Actual queries:  338
# Timed out trying again...
# Queried songs:  3000
# Actual queries:  474
# Queried songs:  4000
# Actual queries:  606
# Queried songs:  5000
# Actual queries:  705
# Queried songs:  6000
# Actual queries:  828
# Queried songs:  7000
# Actual queries:  976
# Queried songs:  8000
# Actual queries:  1114
# Queried songs:  9000
# Actual queries:  1206
# Queried songs:  10000
# Actual queries:  1320
# Queried songs:  11000
# Actual queries:  1405
# Queried songs:  12000
# Actual queries:  1501
# Queried songs:  13000
# Actual queries:  1584
# Queried songs:  14000
# Actual queries:  1684
# Queried songs:  15000
# Actual queries:  1801
# Queried songs:  16000
# Actual queries:  1922
# Queried songs:  17000
# Actual queries:  2032
# Queried songs:  18000
# Actual queries:  2127
# Queried songs:  19000
# Actual queries:  2204
# Queried songs:  20000
# Actual queries:  2266
# Queried songs:  21000
# Actual queries:  2358
# Queried songs:  22000
# Actual queries:  2425
# Queried songs:  23000
# Actual queries:  2528
# Queried songs:  24000
# Actual queries:  2611
# Queried songs:  25000
# Actual queries:  2692
# Queried songs:  26000
# Actual queries:  2747
# Queried songs:  27000
# Actual queries:  2814
# Queried songs:  28000
# Actual queries:  2894
# Queried songs:  29000
# Actual queries:  2965
# Queried songs:  30000
# Actual queries:  3034
# Queried songs:  31000
# Actual queries:  3109
# Queried songs:  32000
# Actual queries:  3169
# Queried songs:  33000
# Actual queries:  3231
# Queried songs:  34000
# Actual queries:  3299
# Queried songs:  35000
# Actual queries:  3368
# Queried songs:  36000
# Actual queries:  3429
# Queried songs:  37000
# Actual queries:  3485
# Queried songs:  38000
# Actual queries:  3551
# Queried songs:  39000
# Actual queries:  3607
# Queried songs:  40000
# Actual queries:  3675
# Queried songs:  41000
# Actual queries:  3756
# Queried songs:  42000
# Actual queries:  3821
# Queried songs:  43000
# Actual queries:  3878
# Queried songs:  44000
# Actual queries:  3942
# Queried songs:  45000
# Actual queries:  4001
# Queried songs:  46000
# Actual queries:  4062
# Queried songs:  47000
# Actual queries:  4118
# Queried songs:  48000
# Actual queries:  4171
# Queried songs:  49000
# Actual queries:  4240
# Queried songs:  50000
# Actual queries:  4310
# Queried songs:  51000
# Actual queries:  4393
# Queried songs:  52000
# Actual queries:  4466
# Queried songs:  53000
# Actual queries:  4553
# Queried songs:  54000
# Actual queries:  4635
# Queried songs:  55000
# Actual queries:  4708
# Queried songs:  56000
# Actual queries:  4791
# Queried songs:  57000
# Actual queries:  4865
# Queried songs:  58000
# Actual queries:  4945
# Queried songs:  59000
# Actual queries:  5025
# Queried songs:  60000
# Actual queries:  5097
# Queried songs:  61000
# Actual queries:  5169
# Queried songs:  62000
# Actual queries:  5244
# Queried songs:  63000
# Actual queries:  5304
# Queried songs:  64000
# Actual queries:  5378
# Queried songs:  65000
# Actual queries:  5436
# Queried songs:  66000
# Actual queries:  5485
# Queried songs:  67000
# Actual queries:  5547
# Queried songs:  68000
# Actual queries:  5613
# Queried songs:  69000
# Actual queries:  5677
# Queried songs:  70000
# Actual queries:  5744
# Queried songs:  71000
# Actual queries:  5798
# Queried songs:  72000
# Actual queries:  5853
# Queried songs:  73000
# Actual queries:  5908
# Queried songs:  74000
# Actual queries:  5971
# Queried songs:  75000
# Actual queries:  6042
# Queried songs:  76000
# Actual queries:  6103
# Queried songs:  77000
# Actual queries:  6165
# Queried songs:  78000
# Actual queries:  6226
# Queried songs:  79000
# Actual queries:  6283
# Queried songs:  80000
# Actual queries:  6347
# Queried songs:  81000
# Actual queries:  6412
# Queried songs:  82000
# Actual queries:  6453
# Queried songs:  83000
# Actual queries:  6514
# Queried songs:  84000
# Actual queries:  6565
# Queried songs:  85000
# Actual queries:  6619
# Queried songs:  86000
# Actual queries:  6679
# Queried songs:  87000
# Actual queries:  6727
# Queried songs:  88000
# Actual queries:  6772
# Queried songs:  89000
# Actual queries:  6819
# Queried songs:  90000
# Actual queries:  6874
# Queried songs:  91000
# Actual queries:  6925
# Queried songs:  92000
# Actual queries:  6969
# Queried songs:  93000
# Actual queries:  7018
# Queried songs:  94000
# Actual queries:  7078
# Queried songs:  95000
# Actual queries:  7120
# Queried songs:  96000
# Actual queries:  7187
# Queried songs:  97000
# Actual queries:  7233
# Queried songs:  98000
# Actual queries:  7287
# Queried songs:  99000
# Actual queries:  7342
# Queried songs:  100000
# Actual queries:  7391
# Queried songs:  101000
# Actual queries:  7445
# Queried songs:  102000
# Actual queries:  7490
# Queried songs:  103000
# Actual queries:  7530
# Queried songs:  104000
# Actual queries:  7578
# Queried songs:  105000
# Actual queries:  7620
# Queried songs:  106000
# Actual queries:  7668
# Queried songs:  107000
# Actual queries:  7716
# Queried songs:  108000
# Actual queries:  7765
# Queried songs:  109000
# Actual queries:  7812
# Queried songs:  110000
# Actual queries:  7859
# Queried songs:  111000
# Actual queries:  7914
# Queried songs:  112000
# Actual queries:  7974
# Queried songs:  113000
# Actual queries:  8025
# Queried songs:  114000
# Actual queries:  8075
# Queried songs:  115000
# Actual queries:  8124
# Queried songs:  116000
# Actual queries:  8181
# Queried songs:  117000
# Actual queries:  8238
# Queried songs:  118000
# Actual queries:  8279
# Queried songs:  119000
# Actual queries:  8364
# Queried songs:  120000
# Actual queries:  8412
# Queried songs:  121000
# Actual queries:  8466
# Queried songs:  122000
# Actual queries:  8513
# Queried songs:  123000
# Actual queries:  8566
# Queried songs:  124000
# Actual queries:  8619
# Queried songs:  125000
# Actual queries:  8673
# Queried songs:  126000
# Actual queries:  8723
# Queried songs:  127000
# Actual queries:  8774
# Queried songs:  128000
# Actual queries:  8830
# Queried songs:  129000
# Actual queries:  8879
# Queried songs:  130000
# Actual queries:  8923
# Queried songs:  131000
# Actual queries:  8981
# Queried songs:  132000
# Actual queries:  9035
# Queried songs:  133000
# Actual queries:  9089
# Queried songs:  134000
# Actual queries:  9134
# Queried songs:  135000
# Actual queries:  9193
# Queried songs:  136000
# Actual queries:  9243
# Queried songs:  137000
# Actual queries:  9295
# Queried songs:  138000
# Actual queries:  9360
# Queried songs:  139000
# Actual queries:  9409
# Queried songs:  140000
# Actual queries:  9465
# Queried songs:  141000
# Actual queries:  9519
# Queried songs:  142000
# Actual queries:  9574
# Queried songs:  143000
# Actual queries:  9631
# Queried songs:  144000
# Actual queries:  9690
# Queried songs:  145000
# Actual queries:  9747
# Queried songs:  146000
# Actual queries:  9802
# Queried songs:  147000
# Actual queries:  9868
# Queried songs:  148000
# Actual queries:  9923
# Queried songs:  149000
# Actual queries:  9975
# Queried songs:  150000
# Actual queries:  10034
# Queried songs:  151000
# Actual queries:  10088
# Queried songs:  152000
# Actual queries:  10152
# Queried songs:  153000
# Actual queries:  10206
# Queried songs:  154000
# Actual queries:  10269
# Queried songs:  155000
# Actual queries:  10325
# Queried songs:  156000
# Actual queries:  10388
# Queried songs:  157000
# Actual queries:  10454
# Queried songs:  158000
# Actual queries:  10515
# Queried songs:  159000
# Actual queries:  10583
# Queried songs:  160000
# Actual queries:  10630
# Queried songs:  161000
# Actual queries:  10693
# Queried songs:  162000
# Actual queries:  10752
# Queried songs:  163000
# Actual queries:  10814
# Queried songs:  164000
# Actual queries:  10879
# Queried songs:  165000
# Actual queries:  10933
# Queried songs:  166000
# Actual queries:  10997
# Queried songs:  167000
# Actual queries:  11068
# Queried songs:  168000
# Actual queries:  11120
# Queried songs:  169000
# Actual queries:  11182
# Queried songs:  170000
# Actual queries:  11243
# Queried songs:  171000
# Actual queries:  11304
# Queried songs:  172000
# Actual queries:  11370
# Queried songs:  173000
# Actual queries:  11430
# Queried songs:  174000
# Actual queries:  11497
# Queried songs:  175000
# Actual queries:  11564
# Queried songs:  176000
# Actual queries:  11610
# Queried songs:  177000
# Actual queries:  11672
# Queried songs:  178000
# Actual queries:  11739
# Queried songs:  179000
# Actual queries:  11805
# Queried songs:  180000
# Actual queries:  11866
# Queried songs:  181000
# Actual queries:  11921
# Queried songs:  182000
# Actual queries:  11987
# Queried songs:  183000
# Actual queries:  12049
# Queried songs:  184000
# Actual queries:  12118
# Queried songs:  185000
# Actual queries:  12182
# Queried songs:  186000
# Actual queries:  12232
# Queried songs:  187000
# Actual queries:  12301
# Queried songs:  188000
# Actual queries:  12374
# Queried songs:  189000
# Actual queries:  12434
# Queried songs:  190000
# Actual queries:  12495
# Timed out trying again...
# Queried songs:  191000
# Actual queries:  12552
# Queried songs:  192000
# Actual queries:  12621
# Queried songs:  193000
# Actual queries:  12685
# Queried songs:  194000
# Actual queries:  12752
# Queried songs:  195000
# Actual queries:  12821
# Queried songs:  196000
# Actual queries:  12898
# Queried songs:  197000
# Actual queries:  12958
# Queried songs:  198000
# Actual queries:  13045
# Queried songs:  199000
# Actual queries:  13114
# Queried songs:  200000
# Actual queries:  13185
# Queried songs:  201000
# Actual queries:  13251
# Queried songs:  202000
# Actual queries:  13308
# Queried songs:  203000
# Actual queries:  13372
# Queried songs:  204000
# Actual queries:  13439
# Queried songs:  205000
# Actual queries:  13512
# Queried songs:  206000
# Actual queries:  13585
# Queried songs:  207000
# Actual queries:  13648
# Queried songs:  208000
# Actual queries:  13724
# Queried songs:  209000
# Actual queries:  13792
# Queried songs:  210000
# Actual queries:  13853
# Queried songs:  211000
# Actual queries:  13919
# Queried songs:  212000
# Actual queries:  13974
# Queried songs:  213000
# Actual queries:  14043
# Queried songs:  214000
# Actual queries:  14117
# Queried songs:  215000
# Actual queries:  14202
# Queried songs:  216000
# Actual queries:  14271
# Queried songs:  217000
# Actual queries:  14333
# Queried songs:  218000
# Actual queries:  14412
# Queried songs:  219000
# Actual queries:  14493
# Queried songs:  220000
# Actual queries:  14562
# Queried songs:  221000
# Actual queries:  14633
# Queried songs:  222000
# Actual queries:  14715
# Queried songs:  223000
# Actual queries:  14782
# Queried songs:  224000
# Actual queries:  14852
# Queried songs:  225000
# Actual queries:  14913
# Queried songs:  226000
# Actual queries:  14981
# Queried songs:  227000
# Actual queries:  15062
# Queried songs:  228000
# Actual queries:  15124
# Queried songs:  229000
# Actual queries:  15194
# Queried songs:  230000
# Actual queries:  15270
# Queried songs:  231000
# Actual queries:  15344
# Queried songs:  232000
# Actual queries:  15433
# Queried songs:  233000
# Actual queries:  15510
# Queried songs:  234000
# Actual queries:  15585
# Queried songs:  235000
# Actual queries:  15672
# Queried songs:  236000
# Actual queries:  15754
# Queried songs:  237000
# Actual queries:  15837
# Queried songs:  238000
# Actual queries:  15917
# Queried songs:  239000
# Actual queries:  16011
# Queried songs:  240000
# Actual queries:  16102
# Queried songs:  241000
# Actual queries:  16201
# Queried songs:  242000
# Actual queries:  16290
# Queried songs:  243000
# Actual queries:  16373
# Queried songs:  244000
# Actual queries:  16456
# Queried songs:  245000
# Actual queries:  16542
# Queried songs:  246000
# Actual queries:  16624
# Queried songs:  247000
# Actual queries:  16696
# Queried songs:  248000
# Actual queries:  16779
# Queried songs:  249000
# Actual queries:  16850
# Queried songs:  250000
# Actual queries:  16935
# Queried songs:  251000
# Actual queries:  17016
# Queried songs:  252000
# Actual queries:  17092
# Queried songs:  253000
# Actual queries:  17183
# Queried songs:  254000
# Actual queries:  17260
# Queried songs:  255000
# Actual queries:  17358
# Queried songs:  256000
# Actual queries:  17431
# Queried songs:  257000
# Actual queries:  17529
# Queried songs:  258000
# Actual queries:  17625
# Queried songs:  259000
# Actual queries:  17712
# Queried songs:  260000
# Actual queries:  17812
# Queried songs:  261000
# Actual queries:  17910
# Queried songs:  262000
# Actual queries:  18006
# Timed out trying again...
# Queried songs:  263000
# Actual queries:  18111
# Queried songs:  264000
# Actual queries:  18195
# Queried songs:  265000
# Actual queries:  18288
# Queried songs:  266000
# Actual queries:  18390
# Queried songs:  267000
# Actual queries:  18492
# Queried songs:  268000
# Actual queries:  18594
# Queried songs:  269000
# Actual queries:  18696
# Queried songs:  270000
# Actual queries:  18791
# Queried songs:  271000
# Actual queries:  18888
# Queried songs:  272000
# Actual queries:  18990
# Queried songs:  273000
# Actual queries:  19099
# Queried songs:  274000
# Actual queries:  19195
# Queried songs:  275000
# Actual queries:  19301
# Queried songs:  276000
# Actual queries:  19406
# Queried songs:  277000
# Actual queries:  19494
# Queried songs:  278000
# Actual queries:  19589
# Queried songs:  279000
# Actual queries:  19701
# Queried songs:  280000
# Actual queries:  19793
# Queried songs:  281000
# Actual queries:  19900
# Queried songs:  282000
# Actual queries:  20015
# Queried songs:  283000
# Actual queries:  20134
# Queried songs:  284000
# Actual queries:  20250
# Queried songs:  285000
# Actual queries:  20336
# Queried songs:  286000
# Actual queries:  20438
# Queried songs:  287000
# Actual queries:  20548
# Queried songs:  288000
# Actual queries:  20661
# Queried songs:  289000
# Actual queries:  20762
# Queried songs:  290000
# Actual queries:  20863
# Queried songs:  291000
# Actual queries:  20964
# Queried songs:  292000
# Actual queries:  21058
# Queried songs:  293000
# Actual queries:  21164
# Queried songs:  294000
# Actual queries:  21267
# Queried songs:  295000
# Actual queries:  21371
# Queried songs:  296000
# Actual queries:  21468
# Queried songs:  297000
# Actual queries:  21565
# Queried songs:  298000
# Actual queries:  21665
# Queried songs:  299000
# Actual queries:  21767
# Queried songs:  300000
# Actual queries:  21881
# Queried songs:  301000
# Actual queries:  21975
# Queried songs:  302000
# Actual queries:  22084
# Queried songs:  303000
# Actual queries:  22175
# Queried songs:  304000
# Actual queries:  22278
# Queried songs:  305000
# Actual queries:  22376
# Queried songs:  306000
# Actual queries:  22480
# Queried songs:  307000
# Actual queries:  22575
# Queried songs:  308000
# Actual queries:  22684
# Queried songs:  309000
# Actual queries:  22777
# Queried songs:  310000
# Actual queries:  22879
# Queried songs:  311000
# Actual queries:  22963
# Queried songs:  312000
# Actual queries:  23054
# Queried songs:  313000
# Actual queries:  23163
# Queried songs:  314000
# Actual queries:  23250
# Queried songs:  315000
# Actual queries:  23350
# Queried songs:  316000
# Actual queries:  23445
# Queried songs:  317000
# Actual queries:  23530
# Queried songs:  318000
# Actual queries:  23613
# Queried songs:  319000
# Actual queries:  23691
# Queried songs:  320000
# Actual queries:  23772
# Queried songs:  321000
# Actual queries:  23853
# Queried songs:  322000
# Actual queries:  23921
# Queried songs:  323000
# Actual queries:  23995
# Queried songs:  324000
# Actual queries:  24069
# Queried songs:  325000
# Actual queries:  24155
# Queried songs:  326000
# Actual queries:  24225
# Queried songs:  327000
# Actual queries:  24306
# Queried songs:  328000
# Actual queries:  24387
# From 328487 exact matches: 12572 Duplicates: 304051
# Queried songs:  0
# Actual queries:  0
# Queried songs:  1000
# Actual queries:  1000
# Queried songs:  2000
# Actual queries:  2000
# Timed out trying again...
# Queried songs:  3000
# Actual queries:  3000
# Queried songs:  4000
# Actual queries:  4000
# Queried songs:  5000
# Actual queries:  5000
# Queried songs:  6000
# Actual queries:  6000
# Queried songs:  7000
# Actual queries:  7000
# Queried songs:  8000
# Actual queries:  8000
# Queried songs:  9000
# Actual queries:  9000
# Queried songs:  10000
# Actual queries:  10000
# Queried songs:  11000
# Actual queries:  11000
# From 11864 exact matches: 6892
# Total matched 19464 / 328487

# %% [markdown]
# ### <a id='features'></a>Spotify song features for billboard songs
# The spotify ID information for billboard songs are queried and now the spotify features can be fetched.
#
# These features are used in the model.
#
# **getSpotifyAudioFeatures** will query the audio features from spotify. Results are stored in json file.

# %%
# Query features for billboard songs
hitSongPath = '../data/datasets/spotify/hit_song.json'
billboardHitFeatures = getSpotifyAudioFeatures(api, billboardSpotifyTrackData)
# Save the results
saveJson(billboardHitFeatures, hitSongPath)

# %%
print(billboardHitFeatures[:5])
# Out:
# [{'info': {'spotifyData': {'name': 'Butter', 'songID': '2bgTY4UwhfBYhGT4HUYStN', 'artists': [{'name': 'BTS', 'artistID': '3Nrfpe0tUJi4K4DXYWgMUX'}], 'album': {'name': 'Butter (Hotter, Sweeter, Cooler)', 'albumID': '1HnJKmB4P6Z8RBdLMWx18w', 'totalTracks': 5, 'releaseDate': '2021-06-04'}}, 'searchQuery': 'Butter', 'minMatchingRatioUsed': 100, 'originalData': {'rank': '1', 'song': 'Butter', 'artist': 'BTS', 'last-week': '1', 'peak-rank': '1', 'weeks-on-board': '7', 'date': '2021-07-17'}}, 'features': {'timeSignature': 4, 'durationMS': 164442, 'key': 8, 'mode': 1, 'acousticness': 0.00323, 'danceability': 0.759, 'energy': 0.459, 'instrumentalness': 0, 'liveness': 0.0906, 'loudness': -5.187, 'speechiness': 0.0948, 'valence': 0.695, 'tempo': 109.997}}, {'info': {'spotifyData': {'name': 'good 4 u', 'songID': '4ZtFanR9U6ndgddUvNcjcG', 'artists': [{'name': 'Olivia Rodrigo', 'artistID': '1McMsnEElThX1knmY4oliG'}], 'album': {'name': 'SOUR', 'albumID': '6s84u2TUpR3wdUv4NgKA2j', 'totalTracks': 11, 'releaseDate': '2021-05-21'}}, 'searchQuery': 'Good 4 U', 'minMatchingRatioUsed': 100, 'originalData': {'rank': '2', 'song': 'Good 4 U', 'artist': 'Olivia Rodrigo', 'last-week': '2', 'peak-rank': '1', 'weeks-on-board': '8', 'date': '2021-07-17'}}, 'features': {'timeSignature': 4, 'durationMS': 178147, 'key': 9, 'mode': 1, 'acousticness': 0.335, 'danceability': 0.563, 'energy': 0.664, 'instrumentalness': 0, 'liveness': 0.0849, 'loudness': -5.044, 'speechiness': 0.154, 'valence': 0.688, 'tempo': 166.928}}, {'info': {'spotifyData': {'name': 'Levitating', 'songID': '41z2bSbbtJ9wiIee4RXdi5', 'artists': [{'name': 'Dua Lipa', 'artistID': '6M2wZ9GZgrQXHCFfjv46we'}], 'album': {'name': 'Future Nostalgia (The Moonlight Edition)', 'albumID': '0JeyP8r2hBxYIoxXv11XiX', 'totalTracks': 19, 'releaseDate': '2021-02-11'}}, 'searchQuery': 'Levitating', 'minMatchingRatioUsed': 100, 'originalData': {'rank': '3', 'song': 'Levitating', 'artist': 'Dua Lipa Featuring DaBaby', 'last-week': '4', 'peak-rank': '2', 'weeks-on-board': '40', 'date': '2021-07-17'}}, 'features': {'timeSignature': 4, 'durationMS': 203808, 'key': 6, 'mode': 0, 'acousticness': 0.0561, 'danceability': 0.695, 'energy': 0.884, 'instrumentalness': 0, 'liveness': 0.213, 'loudness': -2.278, 'speechiness': 0.0753, 'valence': 0.914, 'tempo': 103.014}}, {'info': {'spotifyData': {'name': 'MONTERO (Call Me By Your Name)', 'songID': '1SC5rEoYDGUK4NfG82494W', 'artists': [{'name': 'Lil Nas X', 'artistID': '7jVv8c5Fj3E9VhNjxT4snq'}], 'album': {'name': 'MONTERO', 'albumID': '6pOiDiuDQqrmo5DbG0ZubR', 'totalTracks': 15, 'releaseDate': '2021-09-17'}}, 'searchQuery': 'Montero (Call Me By Your Name)', 'minMatchingRatioUsed': 100, 'originalData': {'rank': '5', 'song': 'Montero (Call Me By Your Name)', 'artist': 'Lil Nas X', 'last-week': '8', 'peak-rank': '1', 'weeks-on-board': '15', 'date': '2021-07-17'}}, 'features': {'timeSignature': 4, 'durationMS': 137704, 'key': 8, 'mode': 0, 'acousticness': 0.293, 'danceability': 0.593, 'energy': 0.503, 'instrumentalness': 0, 'liveness': 0.405, 'loudness': -6.725, 'speechiness': 0.22, 'valence': 0.71, 'tempo': 178.781}}, {'info': {'spotifyData': {'name': 'Bad Habits', 'songID': '6PQ88X9TkUIAUIZJHW2upE', 'artists': [{'name': 'Ed Sheeran', 'artistID': '6eUKZXaKkcviH0Ku9w2n3V'}], 'album': {'name': 'Bad Habits', 'albumID': '01NhUvviMytvV12pmJiDZH', 'totalTracks': 1, 'releaseDate': '2021-06-25'}}, 'searchQuery': 'Bad Habits', 'minMatchingRatioUsed': 100, 'originalData': {'rank': '6', 'song': 'Bad Habits', 'artist': 'Ed Sheeran', 'last-week': '5', 'peak-rank': '5', 'weeks-on-board': '2', 'date': '2021-07-17'}}, 'features': {'timeSignature': 4, 'durationMS': 231041, 'key': 11, 'mode': 0, 'acousticness': 0.0469, 'danceability': 0.808, 'energy': 0.897, 'instrumentalness': 3.14e-05, 'liveness': 0.364, 'loudness': -3.712, 'speechiness': 0.0348, 'valence': 0.591, 'tempo': 126.026}}]

# %% [markdown]
# ### <a id='notHits'></a>Random songs with album ids & features for not hit songs

# %% [markdown]
# To use supervised machine learing methods, the model needs examples of the data with labels. To find difference between a billboard song (considered as hit song) and a not billboard song (considered as not hit), the other part of the data is now fetched to be used.
#
# Unfortunately the model needs the not hit samples too to make any sense of the difference (in theory). Just random songs could be fetched from the Spotify API that are not on billboard lists and use them. The problem is: what to search for ?
#
# Solution for this is to use songs that shares the album with a hit song as we do have the album information. Also when the artist is usually the same, there should not be such a big difference in the spotify audio feture perspective than compairing a random song from a random artist. Therefore the line between hit and not hit would be potentially more accurate.
#
# For implementation of this querying **getSongsWithAlbums** does it all.
#
# First it will take the album id for every billboard song element and query the album information.
#
# Next a random sample of the tracks is taken from the songs of the album query results.
#
# If the song is the same as the song used for querying or the song name has blacklisted elements it is ignored.
#
# Song information is parsed and the results are considered to be NOT hit songs.
#
# Finally the results are stored in json file.
#
# Using 5 random songs for every album where every unique billboard song has an album (about 20k) this is going to take a long time.

# %%
# Query non hit songs with album information
numSongsFromAlbum = 5
notHitSongPath = '../data/datasets/spotify/not_hit_song.json'
billboardNOTHitFeatures = getSongsWithAlbums(api, billboardSpotifyTrackData, numSongsFromAlbum)
saveJson(billboardNOTHitFeatures, notHitSongPath)
# Out:
# Query number:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400

# %% [markdown]
# Finally the data can be checked for duplicates. Duplicates are a hit song in not hit songs. These will be removed.
#
# Also if a song do not have spotify song features it will be removed from the final data used in the next steps.

# %%
from data.query.util import loadJson

hitSongPath = '../data/datasets/spotify/hit_song.json'
notHitSongPath = '../data/datasets/spotify/not_hit_song.json'

# First load the saved data
hits = loadJson(hitSongPath)
notHits = loadJson(notHitSongPath)

print(f"Hit songs: {len(hits)}")
print(f"Not Hit songs: {len(notHits)}")
# Out:
# Hit songs: 19464
# Not Hit songs: 83776

# %%
# Check if there are songs without features and create id list
removeFromHits = []
# Check if not hit songs share hit song ids
hitSpotifyIds = set()
for i, hit in enumerate(hits):
    hitSpotifyIds.add(hit['info']['spotifyData']['songID'])
    
    # So if the features is none, one of the values is none or all the values are zeros the song will be added to the list
    if hit['features'] == None or all(value == 0 for value in hit['features'].values()):
        removeFromHits.append(i)

print(f"Empty features: {len(removeFromHits)}")
# Out:
# Empty features: 2

# %% [markdown]
# Just two empty feature sets in all hit songs. Not bad. These will be removed in a bit.
#
# In last cell the set of all hit song spotify ids was created, so now the not hit song ids can be checked not to actually be hit songs.
#
# Also if the features are null they are added to the remove list like hits before.

# %%
removeFromNotHits = []
for i, notHit in enumerate(notHits):
    if notHit['info']['spotifyData']['songID'] in hitSpotifyIds or notHit['features'] == None or all(value == 0 for value in notHit['features'].values()):
        removeFromNotHits.append(i)

print(f"Empty features or actually hits: {len(removeFromNotHits)}")
# Out:
# Empty features or actually hits: 10214

# %% [markdown]
# Almost 10214 songs! It was expected to be a high number as the songs were randomly taken from albums. Let's say a hit song is registered to an album with top hit tracks there's a good possibility to take songs that will appear in the billboard list.
#
# Now the empty feature or duplicate songs will be removed.

# %%
# Delete empty feature hits, reverse so the order is not messed up
for deleteId in list(reversed(removeFromHits)):
    hits.pop(deleteId)
    
# same for not hits
for deleteId in list(reversed(removeFromNotHits)):
    notHits.pop(deleteId)

print(f"Hit songs: {len(hits)}")
print(f"Not Hit songs: {len(notHits)}")
# Out:
# Hit songs: 19462
# Not Hit songs: 73562

# %% [markdown]
# Alright now just store the data like before, the previous data will be overwritten

# %%
saveJson(hits, hitSongPath)
saveJson(notHits, notHitSongPath)

# %% [markdown]
# All the needed data is now stored in JSON files. These are processed in the next section to create the datasets that the model will use.

# %% [markdown]
# ### <a id='dataset_requirements'></a>Requirements
# There are requirements to use the Kaggle and Spotify API. If you do want to actually make the data queries these need the credentials to be. Information how to set the credentials is below. **To just read through what is done in this document you do not need the credentials!**
#
# #### env file
# API credentials are read directly from env.ini file in config folder. You need to create the env.ini file in the config folder. Check the Readme in config folder to see the structure of the env.ini file.
# ##### Kaggle
# Information how to make Kaggle API token: https://www.kaggle.com/docs/api <br /> after token creation check your kaggle.json for the token.
# >If you are using the Kaggle CLI tool, the tool will look for this token at ~/.kaggle/kaggle.json on Linux, OSX, and other UNIX-based operating systems, and at C:\Users<Windows-username>.kaggle\kaggle.json on Windows. If the token is not there, an error will be raised. Hence, once you’ve downloaded the token, you should move it from your Downloads folder to this folder.
#
# #### Spotify
# Spotify credentials can be created at https://developer.spotify.com/dashboard/
# 1. It requires a Spotify account, but if you have one just sign-in.
# 2. After sign-in, go to **Dashboard** and click **Create an app**, fill info and click **Create**.
# 3. The **Dashboard** should now display your app. Click your app and you can find **CLIENT_ID** and **CLIENT_SECRET**.
# 4. Put **CLIENT_ID** and **CLIENT_SECRET** hash (weird string of numbers and letters) to your **env.ini** file, in config folder:
# 'userId' and 'userKey'.
# <br />Done.
